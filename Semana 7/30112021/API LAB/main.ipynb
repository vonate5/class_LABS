# %% [markdown]
# ##  Imports

# %%
import pandas as pd
import requests
import json
import matplotlib
# %matplotlib inline

# %%
base = 'https://api.coingecko.com/api/v3/'

# %%
url = base + 'coins/bitcoin/market_chart?vs_currency=usd&days=30'

# %%
url
# Out:
# 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=usd&days=30'

# %%
result = requests.get(url)
j_bc = result.json()

# %%
df_bc = pd.DataFrame(j_bc['prices'], columns=['time', 'price'])
df_bc.head(30)
# Out:
#              time         price
# 0   1635703647083  60780.684005
# 1   1635706833298  60859.058541
# 2   1635710689232  60797.915285
# 3   1635714049109  61059.778572
# 4   1635717755725  61564.920919
# 5   1635721258788  61472.844726
# 6   1635725007402  61367.725644
# 7   1635728421286  61569.098571
# 8   1635732570710  61331.467774
# 9   1635735701957  60466.792465
# 10  1635740145965  59979.030236
# 11  1635742881666  60742.423166
# 12  1635746525679  60714.403094
# 13  1635750182582  60873.448629
# 14  1635753613621  62194.929655
# 15  1635757392276  61853.355398
# 16  1635761021909  62043.198186
# 17  1635764777623  62302.431084
# 18  1635768006277  61947.472150
# 19  1635771788669  61921.807870
# 20  1635775726401  61993.752164
# 21  1635778812424  61482.256097
# 22  1635782938681  61580.793138
# 23  1635786144291  61173.140227
# 24  1635789743060  60866.877845
# 25  1635793229405  60722.187867
# 26  1635796828992  61115.849223
# 27  1635800436593  60767.155034
# 28  1635804291982  60950.819200
# 29  1635807632354  61185.320289

# %% [markdown]
# # Bitcoin market value for last 30 days, vs. USD, deliver a DF and a Plot

# %%
param_dict = { 'id':'bitcoin', 'vs_currency':'usd', 'days':30}

# %%
result = requests.get(url, params=param_dict)

# %%
j_dc = result.json()
df_dc = pd.DataFrame(j_dc['prices'], columns=['time', 'price'])
df_dc.head(30)
# Out:
#              time         price
# 0   1635703647083  60780.684005
# 1   1635706833298  60859.058541
# 2   1635710689232  60797.915285
# 3   1635714049109  61059.778572
# 4   1635717755725  61564.920919
# 5   1635721258788  61472.844726
# 6   1635725007402  61367.725644
# 7   1635728421286  61569.098571
# 8   1635732570710  61331.467774
# 9   1635735701957  60466.792465
# 10  1635740145965  59979.030236
# 11  1635742881666  60742.423166
# 12  1635746525679  60714.403094
# 13  1635750182582  60873.448629
# 14  1635753613621  62194.929655
# 15  1635757392276  61853.355398
# 16  1635761021909  62043.198186
# 17  1635764777623  62302.431084
# 18  1635768006277  61947.472150
# 19  1635771788669  61921.807870
# 20  1635775726401  61993.752164
# 21  1635778812424  61482.256097
# 22  1635782938681  61580.793138
# 23  1635786144291  61173.140227
# 24  1635789743060  60866.877845
# 25  1635793229405  60722.187867
# 26  1635796828992  61115.849223
# 27  1635800436593  60767.155034
# 28  1635804291982  60950.819200
# 29  1635807632354  61185.320289

# %%
df_bc = pd.DataFrame(j_bc['prices'], columns=['time', 'price'])
df_bc['time'] = pd.to_datetime(df_bc['time'], unit='ms')

# %%
df_bc.set_index('time', inplace=True)
df_bc.head(30)
# Out:
#                                 price
# time
# 2021-10-31 18:07:27.083  60780.684005
# 2021-10-31 19:00:33.298  60859.058541
# 2021-10-31 20:04:49.232  60797.915285
# 2021-10-31 21:00:49.109  61059.778572
# 2021-10-31 22:02:35.725  61564.920919
# 2021-10-31 23:00:58.788  61472.844726
# 2021-11-01 00:03:27.402  61367.725644
# 2021-11-01 01:00:21.286  61569.098571
# 2021-11-01 02:09:30.710  61331.467774
# 2021-11-01 03:01:41.957  60466.792465
# 2021-11-01 04:15:45.965  59979.030236
# 2021-11-01 05:01:21.666  60742.423166
# 2021-11-01 06:02:05.679  60714.403094
# 2021-11-01 07:03:02.582  60873.448629
# 2021-11-01 08:00:13.621  62194.929655
# 2021-11-01 09:03:12.276  61853.355398
# 2021-11-01 10:03:41.909  62043.198186
# 2021-11-01 11:06:17.623  62302.431084
# 2021-11-01 12:00:06.277  61947.472150
# 2021-11-01 13:03:08.669  61921.807870
# 2021-11-01 14:08:46.401  61993.752164
# 2021-11-01 15:00:12.424  61482.256097
# 2021-11-01 16:08:58.681  61580.793138
# 2021-11-01 17:02:24.291  61173.140227
# 2021-11-01 18:02:23.060  60866.877845
# 2021-11-01 19:00:29.405  60722.187867
# 2021-11-01 20:00:28.992  61115.849223
# 2021-11-01 21:00:36.593  60767.155034
# 2021-11-01 22:04:51.982  60950.819200
# 2021-11-01 23:00:32.354  61185.320289

# %%
df_dc = pd.DataFrame(j_dc['prices'], columns=['time', 'price'])
df_dc['time'] = pd.to_datetime(df_dc['time'], unit='ms')

df_dc.set_index('time', inplace=True)
df_dc.head(30)
# Out:
#                                 price
# time
# 2021-10-31 18:07:27.083  60780.684005
# 2021-10-31 19:00:33.298  60859.058541
# 2021-10-31 20:04:49.232  60797.915285
# 2021-10-31 21:00:49.109  61059.778572
# 2021-10-31 22:02:35.725  61564.920919
# 2021-10-31 23:00:58.788  61472.844726
# 2021-11-01 00:03:27.402  61367.725644
# 2021-11-01 01:00:21.286  61569.098571
# 2021-11-01 02:09:30.710  61331.467774
# 2021-11-01 03:01:41.957  60466.792465
# 2021-11-01 04:15:45.965  59979.030236
# 2021-11-01 05:01:21.666  60742.423166
# 2021-11-01 06:02:05.679  60714.403094
# 2021-11-01 07:03:02.582  60873.448629
# 2021-11-01 08:00:13.621  62194.929655
# 2021-11-01 09:03:12.276  61853.355398
# 2021-11-01 10:03:41.909  62043.198186
# 2021-11-01 11:06:17.623  62302.431084
# 2021-11-01 12:00:06.277  61947.472150
# 2021-11-01 13:03:08.669  61921.807870
# 2021-11-01 14:08:46.401  61993.752164
# 2021-11-01 15:00:12.424  61482.256097
# 2021-11-01 16:08:58.681  61580.793138
# 2021-11-01 17:02:24.291  61173.140227
# 2021-11-01 18:02:23.060  60866.877845
# 2021-11-01 19:00:29.405  60722.187867
# 2021-11-01 20:00:28.992  61115.849223
# 2021-11-01 21:00:36.593  60767.155034
# 2021-11-01 22:04:51.982  60950.819200
# 2021-11-01 23:00:32.354  61185.320289

# %%
df_bc.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# # Litecoin market value for last 30 days, vs. USD, deliver a DF and a Plot

# %%
url1 = base + 'coins/litecoin/market_chart?vs_currency=usd&days=30'

# %%
url1
# Out:
# 'https://api.coingecko.com/api/v3/coins/litecoin/market_chart?vs_currency=usd&days=30'

# %%
result1 = requests.get(url1)
j1_bc = result.json()

# %%
df1_bc = pd.DataFrame(j1_bc['prices'], columns=['time', 'price'])
df1_bc.head(30)
# Out:
#              time         price
# 0   1635703647083  60780.684005
# 1   1635706833298  60859.058541
# 2   1635710689232  60797.915285
# 3   1635714049109  61059.778572
# 4   1635717755725  61564.920919
# 5   1635721258788  61472.844726
# 6   1635725007402  61367.725644
# 7   1635728421286  61569.098571
# 8   1635732570710  61331.467774
# 9   1635735701957  60466.792465
# 10  1635740145965  59979.030236
# 11  1635742881666  60742.423166
# 12  1635746525679  60714.403094
# 13  1635750182582  60873.448629
# 14  1635753613621  62194.929655
# 15  1635757392276  61853.355398
# 16  1635761021909  62043.198186
# 17  1635764777623  62302.431084
# 18  1635768006277  61947.472150
# 19  1635771788669  61921.807870
# 20  1635775726401  61993.752164
# 21  1635778812424  61482.256097
# 22  1635782938681  61580.793138
# 23  1635786144291  61173.140227
# 24  1635789743060  60866.877845
# 25  1635793229405  60722.187867
# 26  1635796828992  61115.849223
# 27  1635800436593  60767.155034
# 28  1635804291982  60950.819200
# 29  1635807632354  61185.320289

# %%
param_dict1 = { 'id':'litecoin', 'vs_currency':'usd', 'days':30}

# %%
result1 = requests.get(url, params=param_dict1)

# %%
j1_dc = result.json()
df1_dc = pd.DataFrame(j_dc['prices'], columns=['time', 'price'])
df1_dc.head(30)
# Out:
#              time         price
# 0   1635703647083  60780.684005
# 1   1635706833298  60859.058541
# 2   1635710689232  60797.915285
# 3   1635714049109  61059.778572
# 4   1635717755725  61564.920919
# 5   1635721258788  61472.844726
# 6   1635725007402  61367.725644
# 7   1635728421286  61569.098571
# 8   1635732570710  61331.467774
# 9   1635735701957  60466.792465
# 10  1635740145965  59979.030236
# 11  1635742881666  60742.423166
# 12  1635746525679  60714.403094
# 13  1635750182582  60873.448629
# 14  1635753613621  62194.929655
# 15  1635757392276  61853.355398
# 16  1635761021909  62043.198186
# 17  1635764777623  62302.431084
# 18  1635768006277  61947.472150
# 19  1635771788669  61921.807870
# 20  1635775726401  61993.752164
# 21  1635778812424  61482.256097
# 22  1635782938681  61580.793138
# 23  1635786144291  61173.140227
# 24  1635789743060  60866.877845
# 25  1635793229405  60722.187867
# 26  1635796828992  61115.849223
# 27  1635800436593  60767.155034
# 28  1635804291982  60950.819200
# 29  1635807632354  61185.320289

# %%
df1_bc.set_index('time', inplace=True)
df1_bc.head(30)
# Out:
#                       price
# time
# 1635703647083  60780.684005
# 1635706833298  60859.058541
# 1635710689232  60797.915285
# 1635714049109  61059.778572
# 1635717755725  61564.920919
# 1635721258788  61472.844726
# 1635725007402  61367.725644
# 1635728421286  61569.098571
# 1635732570710  61331.467774
# 1635735701957  60466.792465
# 1635740145965  59979.030236
# 1635742881666  60742.423166
# 1635746525679  60714.403094
# 1635750182582  60873.448629
# 1635753613621  62194.929655
# 1635757392276  61853.355398
# 1635761021909  62043.198186
# 1635764777623  62302.431084
# 1635768006277  61947.472150
# 1635771788669  61921.807870
# 1635775726401  61993.752164
# 1635778812424  61482.256097
# 1635782938681  61580.793138
# 1635786144291  61173.140227
# 1635789743060  60866.877845
# 1635793229405  60722.187867
# 1635796828992  61115.849223
# 1635800436593  60767.155034
# 1635804291982  60950.819200
# 1635807632354  61185.320289

# %%
df1_bc.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# ## NOTE
# ### I don't know why the litecoin URL ('https://api.coingecko.com/api/v3/coins/litecoin/market_chart?vs_currency=usd&days=30'
# ) doesn't extract the right data... it returns de bitcoin data
#
# If you click on the URL the values of the coin are the right ones...

# %% [markdown]
# ## Plot Litecoin and Dogecoin prices in USD in a lineplot for each for the last 30 days

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # Top Ten Coins Report

# %% [markdown]
# ## List the first 10 coingecko currencies in a DataFrame

# %%
import requests

# %%
coingecko = requests.get("https://www.coingecko.com/es")
print('coingecko;', coingecko.status_code)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-289459c45a7c> in <module>
# ----> 1 print('coingecko;', coingecko.status_code)
#
# AttributeError: 'str' object has no attribute 'status_code'

# %%
google= requests.get("http://developers.google.com")
print('google;', google.status_code)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-edeaca6d1888> in <module>
# ----> 1 coingecko.json()
#
# AttributeError: 'str' object has no attribute 'json'

# %% [markdown]
# ## Make a csv called 'top_ten_report.csv' and check that it worked
