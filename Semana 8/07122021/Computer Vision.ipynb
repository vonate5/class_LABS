# %% [markdown]
# # In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue. Here is an example if you are not sure what to look for.

# %%
from IPython.display import display, Markdown

# %% [markdown]
# [Article or blog which discusses ethical issues with computer vision applications](https://www.brookings.edu/research/solving-the-problem-of-racially-discriminatory-advertising-on-facebook/)

# %% [markdown]
# # Use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %%
# %matplotlib inline
from IPython.display import Image
Image('giraffe by cars.png')

# %% [markdown]
# # read this blog article. Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.

# %% [markdown]
# [The Data Frog](https://thedatafrog.com/en/articles/dogs-vs-cats/)

# %% [markdown]
# The steps  that the author uses are:
# - Initialization
# - A first look at the dogs and cats dataset
# - Pet cleaning: improving the dataset quality
# - Load the dogs and cats image dataset with Keras
# - Pet plotting for label validation
# - Split the training and validation samples with ImageDataGenerator
# - A simple convolutional neural network
# - Data augmentation
# - Using a pre-trained model : ResNet50
# - Conclusion and outlook

# %% [markdown]
# In the pre-trained model : ResNet50 he does the following steps:
# - Import libraries and build the model with a few lines of code
# - Define a small utility function to evaluate the model on an input image
